# %%
from datetime import datetime as dt
import pandas as pd
import pandas_ta as ta
import numpy as np
import torch

# %%
df = pd.read_csv("/Users/stevenwinatamulia/Documents/skripsi-git//Documents/skripsi/ETHUSDT-4h-2020-2024.csv",delimiter=';')

# %%
#change timestamp into datetime
def timestamp_to_datetime(timestamp:list)->list:
    datetime = []
    for i in timestamp:
        datetime.append(dt.fromtimestamp(int(i)/1000))
    return datetime

df['open_time'] = timestamp_to_datetime(df['open_time'])
df['close_time'] = timestamp_to_datetime(df['close_time'])
df.index=df['open_time']

# %% [markdown]
# # feature engineering

# %%
df.columns
# Out:
# Index(['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time',
#        'quote_volume', 'count', 'taker_buy_volume', 'taker_buy_quote_volume',
#        'ignore'],
#       dtype='object')

# %%
df['SMA_50'] = ta.sma(df['close'], 50)
df['RSI_14'] = ta.rsi(df['close'], 14)
df['RSI_21'] = ta.rsi(df['close'],21)
df['EMA_20'] = ta.ema(df['close'], 20)
df['EMA_34'] = ta.ema(df['close'], 34)
df = df.join(ta.bbands(df['close'], length=20, std=2))
df = df.join(ta.macd(df['close'], fast=12, slow=26, signal=9))
#df['BB_upper'], df['BB_middle'], df['BB_lower'] = ta.bbands(df['close'], length=20, std=2)
#df['MACD'], df['MACD_signal'], df['MACD_hist'] = ta.macd(df['close'], fast=12, slow=26, signal=9)

# %%
df['SMA_50'] = ta.sma(df['close'], 50)
df['RSI_14'] = ta.rsi(df['close'], 14)
df['RSI_21'] = ta.rsi(df['close'],21)
df['EMA_20'] = ta.ema(df['close'], 20)
df['EMA_34'] = ta.ema(df['close'], 34)
#df['BB_upper'], df['BB_middle'], df['BB_lower'] = ta.bbands(df['close'], length=20, std=2)
# df['MACD'], df['MACD_signal'], df['MACD_hist'] = ta.macd(df['close'], fast=12, slow=26, signal=9)
df_fix = df[[ 'open', 'high', 'low', 'close', 'volume','SMA_50', 'RSI_14', 'EMA_20','RSI_21','EMA_34']]

# %%
ta.bbands(df['close'], length=31, std=2)
# Out:
#                       BBL_31_2.0   BBM_31_2.0   BBU_31_2.0  BBB_31_2.0  \
# open_time
# 2020-01-01 07:00:00          NaN          NaN          NaN         NaN
# 2020-01-01 11:00:00          NaN          NaN          NaN         NaN
# 2020-01-01 15:00:00          NaN          NaN          NaN         NaN
# 2020-01-01 19:00:00          NaN          NaN          NaN         NaN
# 2020-01-01 23:00:00          NaN          NaN          NaN         NaN
# ...                          ...          ...          ...         ...
# 2024-09-30 11:00:00  2584.613009  2647.771935  2710.930862    4.770723
# 2024-09-30 15:00:00  2585.221383  2648.014839  2710.808294    4.742682
# 2024-09-30 19:00:00  2581.890137  2647.006452  2712.122766    4.919997
# 2024-09-30 23:00:00  2581.184728  2646.831935  2712.479143    4.960436
# 2024-10-01 03:00:00  2586.191157  2647.857742  2709.524327    4.657847
#
#                      BBP_31_2.0
# open_time
# 2020-01-01 07:00:00         NaN
# 2020-01-01 11:00:00         NaN
# 2020-01-01 15:00:00         NaN
# 2020-01-01 19:00:00         NaN
# 2020-01-01 23:00:00         NaN
# ...                         ...
# 2024-09-30 11:00:00    0.412349
# 2024-09-30 15:00:00    0.340391
# 2024-09-30 19:00:00    0.101049
# 2024-09-30 23:00:00    0.101339
# 2024-10-01 03:00:00    0.124045
#
# [10387 rows x 5 columns]

# %%
import numpy as np

# %%
log_ret = pd.DataFrame()
log_ret['ret_close'] = np.log(df_fix.close) - np.log(df_fix.close.shift(1))
log_ret['sma50'] = df_fix['SMA_50']
log_ret['rsi14'] = df_fix['RSI_14']
log_ret['ema20'] = df_fix['EMA_20']
log_ret['rsi21'] = df_fix['RSI_21']
log_ret['ema34'] = df_fix['EMA_34']
log_ret = log_ret.join(ta.bbands(df['close'], length=30, std=2))
log_ret = log_ret.join(ta.bbands(df['close'], length=31, std=2))
log_ret = log_ret.join(ta.macd(df['close'], fast=12, slow=26, signal=9))
log_ret = log_ret.dropna()

# %%
log_ret.corr(method='spearman').iloc[0].shape[0]
# Out:
# 19

# %%
log_ret.corr(method='spearman').iloc[0]
# Out:
# ret_close        1.000000
# sma50           -0.028847
# rsi14            0.298451
# ema20           -0.026924
# rsi21            0.242974
# ema34           -0.027870
# BBL_30_2.0      -0.028151
# BBM_30_2.0      -0.028307
# BBU_30_2.0      -0.028107
# BBB_30_2.0       0.018476
# BBP_30_2.0       0.299018
# BBL_31_2.0      -0.028132
# BBM_31_2.0      -0.028291
# BBU_31_2.0      -0.028164
# BBB_31_2.0       0.017872
# BBP_31_2.0       0.293958
# MACD_12_26_9     0.048334
# MACDh_12_26_9    0.125265
# MACDs_12_26_9    0.009885
# Name: ret_close, dtype: float64

# %%
correlation = []
for i in range(log_ret.corr(method='spearman').iloc[0].shape[0]):
    if np.abs(log_ret.corr(method='spearman').iloc[0][i]) >=0.1:
        correlation.append(i)
        print(i)
# Out:
# /var/folders/_8/r2326rms4l37yskjs2yv3mv80000gn/T/ipykernel_12732/2321901921.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if np.abs(log_ret.corr(method='spearman').iloc[0][i]) >=0.1:
# 0
# 2
# 4
# 10
# 15
# 17

# %%
col_name = log_ret.corr(method='spearman').iloc[0][correlation].index
col_name
# Out:
# /var/folders/_8/r2326rms4l37yskjs2yv3mv80000gn/T/ipykernel_12732/579759620.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   col_name = log_ret.corr(method='spearman').iloc[0][correlation].index
# Index(['ret_close', 'rsi14', 'rsi21', 'BBP_30_2.0', 'BBP_31_2.0',
#        'MACDh_12_26_9'],
#       dtype='object')

# %% [markdown]
# # Data Fix (after cleaning and engineering)

# %%
XY_data = log_ret[col_name]
XY_data.head()
# Out:
#                      ret_close      rsi14      rsi21  BBP_30_2.0  BBP_31_2.0  \
# open_time
# 2020-01-09 11:00:00  -0.000143  50.827852  53.502023    0.533342    0.545253
# 2020-01-09 15:00:00  -0.012225  46.592383  50.203579    0.395587    0.412719
# 2020-01-09 19:00:00  -0.000651  46.372073  50.032115    0.368387    0.390964
# 2020-01-09 23:00:00  -0.004281  44.874082  48.882925    0.298975    0.325386
# 2020-01-10 03:00:00   0.001453  45.516591  49.297440    0.293984    0.320568
#
#                      MACDh_12_26_9
# open_time
# 2020-01-09 11:00:00      -0.758915
# 2020-01-09 15:00:00      -0.859642
# 2020-01-09 19:00:00      -0.900565
# 2020-01-09 23:00:00      -0.931715
# 2020-01-10 03:00:00      -0.902566

# %%
XY_data.corr()
# Out:
#                ret_close     rsi14     rsi21  BBP_30_2.0  BBP_31_2.0  \
# ret_close       1.000000  0.330811  0.279739    0.342928    0.337632
# rsi14           0.330811  1.000000  0.977887    0.937837    0.940638
# rsi21           0.279739  0.977887  1.000000    0.879963    0.886131
# BBP_30_2.0      0.342928  0.937837  0.879963    1.000000    0.999105
# BBP_31_2.0      0.337632  0.940638  0.886131    0.999105    1.000000
# MACDh_12_26_9   0.154010  0.499070  0.393082    0.549837    0.542351
#
#                MACDh_12_26_9
# ret_close           0.154010
# rsi14               0.499070
# rsi21               0.393082
# BBP_30_2.0          0.549837
# BBP_31_2.0          0.542351
# MACDh_12_26_9       1.000000

# %%
XY_data['y'] = XY_data['ret_close'].shift(-1)
XY_data.tail()
# Out:
# /var/folders/_8/r2326rms4l37yskjs2yv3mv80000gn/T/ipykernel_12732/2773508375.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   XY_data['y'] = XY_data['ret_close'].shift(-1)
#                      ret_close      rsi14      rsi21  BBP_30_2.0  BBP_31_2.0  \
# open_time
# 2024-09-30 11:00:00   0.003062  46.236617  50.622382    0.405491    0.412349
# 2024-09-30 15:00:00  -0.003316  43.949577  49.088132    0.336007    0.340391
# 2024-09-30 19:00:00  -0.012606  36.598073  43.828611    0.080785    0.101049
# 2024-09-30 23:00:00  -0.000216  36.486268  43.744894    0.044491    0.101339
# 2024-10-01 03:00:00   0.002694  38.995063  45.120723    0.074759    0.124045
#
#                      MACDh_12_26_9         y
# open_time
# 2024-09-30 11:00:00      -6.855071 -0.003316
# 2024-09-30 15:00:00      -7.393437 -0.012606
# 2024-09-30 19:00:00      -9.526301 -0.000216
# 2024-09-30 23:00:00     -10.459905  0.002694
# 2024-10-01 03:00:00     -10.086594       NaN

# %% [markdown]
# # very fix data
#
# XY_data

# %%
# XY_data.to_csv('data_skripsi.csv')

# %% [markdown]
# bawahnya gw ilangin karena gaada y lagi (run out of y) -> log ret udah gada lagi.

# %%
XY_data.index = df.open_time.iloc[10387-10338:]

# %%
dataX = XY_data.iloc[:-1,:-1]
dataY = XY_data.iloc[5:-1,-1]
dataX.shape
# Out:
# (10337, 6)

# %%
dataY.shape
# Out:
# (10332,)

# %% [markdown]
# ## Setting the Training and Testing Data

# %%
X_train = dataX[:7749].values.astype('float32')
y_train = dataY[:7749-6].values.astype('float32')
print(X_train.shape,y_train.shape)
# Out:
# (7749, 6) (7743,)

# %%
X_train_modified = []

for i in range(len(X_train)-6):
    X_train_modified.append(X_train[i:i+6])

# %%
X_train_tensor = torch.from_numpy(np.array(X_train_modified))
y_train_tensor = torch.from_numpy(y_train).view(-1, 1)

# %%
X_train_tensor.shape
# Out:
# torch.Size([7743, 6, 6])

# %%
y_train_tensor.shape
# Out:
# torch.Size([7743, 1])

# %%
X_test = dataX[7749:].values.astype('float32')
y_test = dataY[7749:].values.astype('float32')
print(X_test.shape,y_test.shape)
# Out:
# (2588, 6) (2583,)

# %%
X_test_modified = []

for i in range(len(X_test)-5):
    X_test_modified.append(X_test[i:i+6])

# %%
X_test_tensor = torch.from_numpy(np.array(X_test_modified))
y_test_tensor = torch.from_numpy(y_test).view(-1, 1)

# %%
print(X_test_tensor.shape,y_test_tensor.shape)
# Out:
# torch.Size([2583, 6, 6]) torch.Size([2583, 1])

# %%
X_train_check = dataX[:7749]#.values.astype('float32')
y_train_check = dataY[:7749-5]#.values.astype('float32')
X_test_check = dataX[7749:]#.values.astype('float32')
y_test_check = dataY[7749:]#.values.astype('float32')

# %%
X_test_check
# Out:
#                      ret_close      rsi14      rsi21  BBP_30_2.0  BBP_31_2.0  \
# open_time
# 2023-07-27 19:00:00  -0.004429  50.069085  48.036260    0.568400    0.550972
# 2023-07-27 23:00:00  -0.004174  45.110592  45.060578    0.425759    0.413731
# 2023-07-28 03:00:00   0.000188  45.372689  45.220869    0.436982    0.434348
# 2023-07-28 07:00:00   0.000935  46.734407  46.042634    0.478325    0.474318
# 2023-07-28 11:00:00  -0.001876  44.346604  44.632536    0.414059    0.405847
# ...                        ...        ...        ...         ...         ...
# 2024-09-30 07:00:00  -0.010468  43.726106  49.227030    0.347818    0.345992
# 2024-09-30 11:00:00   0.003062  46.236617  50.622382    0.405491    0.412349
# 2024-09-30 15:00:00  -0.003316  43.949577  49.088132    0.336007    0.340391
# 2024-09-30 19:00:00  -0.012606  36.598073  43.828611    0.080785    0.101049
# 2024-09-30 23:00:00  -0.000216  36.486268  43.744894    0.044491    0.101339
#
#                      MACDh_12_26_9
# open_time
# 2023-07-27 19:00:00       3.240137
# 2023-07-27 23:00:00       2.234370
# 2023-07-28 03:00:00       1.542062
# 2023-07-28 07:00:00       1.167708
# 2023-07-28 11:00:00       0.675838
# ...                            ...
# 2024-09-30 07:00:00      -6.469585
# 2024-09-30 11:00:00      -6.855071
# 2024-09-30 15:00:00      -7.393437
# 2024-09-30 19:00:00      -9.526301
# 2024-09-30 23:00:00     -10.459905
#
# [2588 rows x 6 columns]

# %% [markdown]
# # Setting Batch Size

# %%
from torch.utils.data import Dataset, DataLoader

class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
train_dataset = CustomDataset(X_train_tensor, y_train_tensor)
test_dataset = CustomDataset(X_test_tensor, y_test_tensor)

# %%
batch_size = 16  # You can adjust this based on your needs

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Setting Models

# %%
import torch
from torch import nn # nn contains all of PyTorch's building blocks for neural networks
import matplotlib.pyplot as plt

# %%
class RNNModel(nn.Module):
    def __init__(self, input_size=X_train_tensor.shape[-1], hidden_size_1=64, hidden_size_2=32, hidden_size_3=16, output_size=1):
        super(RNNModel, self).__init__()
        
        # First RNN layer
        self.layer1 = nn.RNN(input_size=input_size, 
                          hidden_size=hidden_size_1,
                          batch_first=True)
        
        # Second RNN layer
        self.layer2 = nn.RNN(input_size=hidden_size_1,
                          hidden_size=hidden_size_2,
                          batch_first=True)
        
        # Third RNN layer
        self.layer3 = nn.RNN(input_size=hidden_size_2,
                          hidden_size=hidden_size_3,
                          batch_first=True)
        
        # Final linear layer
        self.fc = nn.Linear(hidden_size_3, output_size)
        
    def forward(self, x):
        # Reshape input if it's not in the right format
        if len(x.shape) == 2:
            x = x.unsqueeze(1)  # Add sequence length dimension
            
        # First RNN layer
        out, _ = self.layer1(x)
        
        # Second RNN layer
        out, _ = self.layer2(out)
        
        # Third RNN layer
        out, _ = self.layer3(out)
        
        # Take the last output and pass through final linear layer
        out = self.fc(out[:, -1, :])
        
        return out

# %%
# Set manual seed since nn.Parameter are randomly initialized
torch.manual_seed(42)

# Create an instance of the model (this is a subclass of nn.Module that contains nn.Parameter(s))
model_0 = RNNModel()

# %%
print('parameter before training: ')
list(model_0.parameters())
# Out:
# parameter before training:
# [Parameter containing:
#  tensor([[ 0.0956,  0.1038, -0.0293,  0.1148, -0.0274,  0.0252],
#          [-0.0609,  0.0734,  0.1102, -0.0917,  0.1086,  0.0234],
#          [ 0.0924,  0.0169,  0.0603, -0.0176,  0.0964,  0.0185],
#          [-0.0584,  0.0319, -0.0576, -0.0147, -0.0508,  0.0829],
#          [-0.0987, -0.0576, -0.0353, -0.0752,  0.0118, -0.1235],
#          [ 0.1129, -0.1062,  0.0965,  0.0208, -0.0406,  0.0772],
#          [ 0.0195,  0.1010,  0.0137, -0.0394,  0.0336, -0.0339],
#          [ 0.0526,  0.1116,  0.0723, -0.0546,  0.0722,  0.0224],
#          [ 0.0635, -0.0762, -0.1237, -0.0483, -0.0959,  0.1026],
#          [ 0.0360,  0.0518,  0.0395, -0.0022,  0.0978, -0.0888],
#          [ 0.0079, -0.0853,  0.0385, -0.0430,  0.0383, -0.0260],
#          [ 0.1037, -0.0741, -0.0745, -0.0746,  0.1124,  0.0417],
#          [ 0.1203, -0.1032, -0.1240, -0.0978, -0.0841,  0.0506],
#          [ 0.0448,  0.1039, -0.0646, -0.0852,  0.0663, -0.0505],
#          [ 0.0759, -0.0297,  0.0715, -0.0971, -0.0631,  0.0381],
#          [ 0.0264, -0.0319,  0.0745,  0.0850, -0.0906, -0.0667],
#          [ 0.1145, -0.0422, -0.0443, -0.1209, -0.0716,  0.0312],
#          [-0.0165, -0.0907,  0.0029, -0.0854, -0.1060, -0.0688],
#          [-0.1094, -0.0796,  0.1250,  0.0236,  0.0385, -0.1166],
#          [-0.0821, -0.0416,  0.0195, -0.1100, -0.0539, -0.0748],
#          [ 0.0003, -0.0465, -0.0087, -0.0847, -0.0858, -0.0729],
#          [-0.0428, -0.0987,  0.1048, -0.0248,  0.1075,  0.0389],
#          [-0.1058,  0.0865, -0.0344, -0.0479, -0.1038, -0.1243],
#          [ 0.0358, -0.0273,  0.0487, -0.1026,  0.0928, -0.0918],
#          [-0.0216,  0.0261,  0.0645,  0.1009,  0.1139, -0.0991],
#          [ 0.0315, -0.0538, -0.0137, -0.0936,  0.1139, -0.0917],
#          [ 0.0668,  0.0439,  0.0406, -0.0676,  0.1136,  0.0275],
#          [ 0.0161, -0.1102,  0.0525, -0.0188, -0.0573,  0.1074],
#          [ 0.0279, -0.0692, -0.0633, -0.0060,  0.0698, -0.0319],
#          [-0.0713, -0.0428, -0.0934,  0.0446,  0.0968, -0.1177],
#          [ 0.0290,  0.0646,  0.0227, -0.0445,  0.0652,  0.0657],
#          [ 0.0467, -0.0220, -0.0331,  0.0134, -0.0221, -0.0373],
#          [-0.1093,  0.1181,  0.2184,  0.1353, -0.0527, -0.1963, -0.2064, -0.0599,
#           -0.0788, -0.1896,  0.0618, -0.0947,  0.0725, -0.1328, -0.0225, -0.0752],
#          [ 0.1536, -0.2282, -0.0986,  0.0534, -0.0704, -0.0043,  0.1690,  0.0358,
#            0.0308,  0.0730, -0.1345, -0.0998,  0.1198,  0.0362,  0.1631, -0.0319],
#          [ 0.2349,  0.1493, -0.0700, -0.1278,  0.0505, -0.2086, -0.1145,  0.0766,
#            0.0218,  0.1131, -0.1046,  0.2104, -0.1375, -0.1281,  0.1673, -0.0482],
#          [ 0.0715, -0.0444, -0.1768, -0.0100,  0.1134,  0.1685,  0.1907, -0.0088,
#            0.1811,  0.0705,  0.0093,  0.0047, -0.0239,  0.0714, -0.0129,  0.1608]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.0381, -0.1388,  0.0727, -0.1401,  0.1553,  0.2042,  0.0401, -0.0502,
#          -0.0113,  0.1171, -0.1910, -0.0669, -0.1523, -0.2261, -0.1789, -0.1606],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.1904,  0.1528, -0.1697, -0.1973,  0.2239,  0.0593,  0.1151,  0.0390,
#          -0.0934, -0.1351,  0.1345, -0.2470, -0.2080,  0.0755, -0.0656,  0.0478],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.1333, -0.1437, -0.1407, -0.1538, -0.2187, -0.0169,  0.2123, -0.0153,
#            0.1371, -0.1243,  0.0248, -0.1877, -0.0165,  0.0549, -0.1070,  0.2295]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0.0706], requires_grad=True)]

# %% [markdown]
# ### Setting Loss Function and Optimizer for NN training

# %%
# Create the loss function
loss_fn = nn.MSELoss()


# Create the optimizer
optimizer = torch.optim.Adam(params=model_0.parameters(), # parameters of target model to optimize
                            lr=0.000001)

# %%
import time

# %%
torch.manual_seed(42)

# Set the number of epochs
epochs = 50

# Create empty loss lists to track values
train_loss_values = []
test_loss_values = []
epoch_count = []

epoch_start_time = time.time()  # Start time for total training

for epoch in range(1,1+epochs):
    ### Training
    model_0.train()  # Put model in training mode
    train_loss = 0  # Track total training loss for the epoch
    iteration = 0
    # Iterate over batches in the training DataLoader
    for X_batch, y_batch in train_loader:
        # 1. Forward pass on train data
        y_pred = model_0(X_batch)

        # 2. Calculate the loss
        loss = loss_fn(y_pred, y_batch)

        # 3. Zero grad of the optimizer clears the gradients of all optimized tensors.
        optimizer.zero_grad()

        # 4. Loss backwards
        # This function computes the gradients of the loss with respect to the model parameters using backpropagation.
        loss.backward()

        # 5. Progress the optimizer
        
        optimizer.step()

        # Accumulate the training loss for the epoch
        train_loss += loss.item()

    # Calculate average training loss for the epoch
    train_loss /= len(train_loader)

    ### Testing
    model_0.eval()  # Put the model in evaluation mode
    y_preds = []
    test_loss = 0  # Track total testing loss for the epoch

    with torch.inference_mode():
        # Iterate over batches in the test DataLoader
        for X_batch, y_batch in test_loader:
            # 1. Forward pass on test data
            test_pred = model_0(X_batch)

            # 2. Calculate loss on test data
            test_loss += loss_fn(test_pred, y_batch).item()

        # Calculate average testing loss for the epoch
        test_loss /= len(test_loader)
    
    epoch_time = time.time() - epoch_start_time

    # Print out what's happening
    if epoch % 10 == 0:
        epoch_count.append(epoch)
        train_loss_values.append(train_loss)
        test_loss_values.append(test_loss)
        print(f"Epoch: {epoch:.6f} | MSE Train Loss: {train_loss:.6f} | MSE Test Loss: {test_loss}")

# total_time = time.time() - epoch_start_time
# print(f"\nTotal training time: {total_time:.2f} seconds, batch size is {batch_size} and epoch is {epochs}")
# Out:
# Epoch: 10.000000 | MSE Train Loss: 0.001589 | MSE Test Loss: 0.0012382675218916884
# Epoch: 20.000000 | MSE Train Loss: 0.000812 | MSE Test Loss: 0.0005754689797340464
# Epoch: 30.000000 | MSE Train Loss: 0.000554 | MSE Test Loss: 0.0003383160418044649
# Epoch: 40.000000 | MSE Train Loss: 0.000461 | MSE Test Loss: 0.0002515997996930691
# Epoch: 50.000000 | MSE Train Loss: 0.000425 | MSE Test Loss: 0.00021562464258963307

# %%
print('parameter after training: ')
list(model_0.parameters())
# Out:
# parameter after training:
# [Parameter containing:
#  tensor([[ 0.0972,  0.1033, -0.0295,  0.1143, -0.0280,  0.0252],
#          [-0.0616,  0.0743,  0.1110, -0.0924,  0.1080,  0.0229],
#          [ 0.0903,  0.0159,  0.0590, -0.0150,  0.0991,  0.0196],
#          [-0.0675,  0.0299, -0.0591, -0.0178, -0.0538,  0.0795],
#          [-0.1000, -0.0596, -0.0376, -0.0738,  0.0130, -0.1212],
#          [ 0.1040, -0.1050,  0.0979,  0.0215, -0.0399,  0.0774],
#          [ 0.0208,  0.0974,  0.0098, -0.0384,  0.0346, -0.0345],
#          [ 0.0516,  0.1120,  0.0727, -0.0547,  0.0722,  0.0215],
#          [ 0.0624, -0.0760, -0.1235, -0.0481, -0.0957,  0.1028],
#          [ 0.0352,  0.0523,  0.0401, -0.0019,  0.0981, -0.0883],
#          [ 0.0014, -0.0824,  0.0411, -0.0375,  0.0439, -0.0255],
#          [ 0.1026, -0.0722, -0.0728, -0.0753,  0.1118,  0.0419],
#          [ 0.1199, -0.1025, -0.1234, -0.0981, -0.0843,  0.0504],
#          [ 0.0365,  0.1040, -0.0640, -0.0873,  0.0643, -0.0533],
#          [ 0.0797, -0.0316,  0.0698, -0.0989, -0.0649,  0.0377],
#          [ 0.0195, -0.0344,  0.0722,  0.0819, -0.0937, -0.0683],
#          [ 0.1142, -0.0379, -0.0400, -0.1219, -0.0726,  0.0284],
#          [-0.0140, -0.0892,  0.0046, -0.0853, -0.1059, -0.0706],
#          [-0.1036, -0.0769,  0.1276,  0.0270,  0.0419, -0.1140],
#          [-0.0922, -0.0389,  0.0227, -0.1080, -0.0518, -0.0815],
#          [ 0.0038, -0.0488, -0.0113, -0.0806, -0.0819, -0.0699],
#          [-0.0499, -0.0997,  0.1041, -0.0270,  0.1053,  0.0366],
#          [-0.1138,  0.0843, -0.0363, -0.0511, -0.1069, -0.1265],
#          [ 0.0449, -0.0219,  0.0537, -0.0961,  0.0992, -0.0841],
#          [-0.0238,  0.0270,  0.0655,  0.1013,  0.1142, -0.0983],
#          [ 0.0323, -0.0548, -0.0153, -0.0879,  0.1195, -0.0891],
#          [ 0.0682,  0.0414,  0.0377, -0.0632,  0.1179,  0.0307],
#          [ 0.0221, -0.1079,  0.0545, -0.0154, -0.0539,  0.1100],
#          [ 0.0297, -0.0712, -0.0654, -0.0042,  0.0716, -0.0301],
#          [-0.0696, -0.0417, -0.0922,  0.0440,  0.0962, -0.1187],
#          [ 0.0318,  0.0652,  0.0234, -0.0440,  0.0657,  0.0647],
#          [ 0.0491, -0.0233, -0.0346,  0.0156, -0.0199, -0.0368],
#          [ 0.0785,  0.1111, -0.0090, -0.0296,  0.0002, -0.0092],
#          [ 0.0310,  0.0350, -0.1136, -0.0461,  0.1053,  0.0489],
#          [-0.0054, -0.0762, -0.0774, -0.1110, -0.0397,  0.0429],
#          [ 0.0839,  0.0582, -0.1103, -0.0740, -0.0186,  0.1196],
#          [ 0.0072, -0.0295,  0.0550, -0.0458, -0.0789,  0.0844],
#          [-0.0559, -0.0259, -0.1253,  0.0845,  0.0955,  0.0462],
#          [-0.0883, -0.1242, -0.1023,  0.0923,  0.0591,  0.1043],
#          [ 0.0735,  0.0310, -0.0025, -0.0936, -0.1057, -0.1075],
#          [ 0.0497, -0.0574, -0.0209, -0.0755, -0.0263, -0.0921],
#          [-0.0906,  0.0448, -0.0336,  0.0803, -0.0368, -0.0914],
#          [-0.0254, -0.0579, -0.0351, -0.1231,  0.0659, -0.0894],
#          [ 0.0614,  0.0568,  0.0895, -0.0962,  0.0896, -0.0591],
#          [ 0.0449,  0.1167, -0.0183, -0.0020, -0.0298, -0.1054],
#          [ 0.0595, -0.1185,  0.0831,  0.0978,  0.1224, -0.0342],
#          [-0.1040,  0.0270,  0.0679, -0.1255, -0.0295, -0.0758],
#          [-0.0120, -0.0597, -0.0493, -0.0382, -0.1173,  0.1040],
#          [ 0.1056, -0.0214, -0.0162, -0.0489, -0.1108, -0.1158],
#          [ 0.0445, -0.0666, -0.0784, -0.0118, -0.0436, -0.0413],
#          [ 0.0044, -0.0273, -0.0439, -0.0604, -0.1023,  0.1039],
#          [-0.0415,  0.0292, -0.0476,  0.0070,  0.1133,  0.0556],
#          [-0.1079,  0.0457,  0.1147,  0.0347,  0.0856,  0.1271],
#          [-0.0237,  0.0246, -0.0881, -0.0277,  0.0906,  0.0633],
#          [-0.0806, -0.0990, -0.0841, -0.1245, -0.0976, -0.0326],
#          [ 0.0845,  0.0200, -0.0961, -0.0978,  0.0645, -0.0917],
#          [-0.0273,  0.0579, -0.0594, -0.0168, -0.0140, -0.0343],
#          [-0.0619, -0.1134, -0.1030, -0.0652,  0.1224, -0.0584],
#          [-0.0881,  0.0326,  0.0371,  0.0640,  0.0907,  0.0664],
#          [-0.1254,  0.0089,  0.0733, -0.0103, -0.0725,  0.1216],
#          [-0.0476, -0.0696, -0.1113,  0.0048,  0.0547,  0.0270],
#          [ 0.0244, -0.0942, -0.1160,  0.0020,  0.1138,  0.0722],
#          [-0.0739, -0.0168, -0.0927, -0.0609,  0.0221,  0.0676],
#          [ 0.1119, -0.1087,  0.0890, -0.0804,  0.0545,  0.1160]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.0016,  0.1135, -0.1067,  ..., -0.0607, -0.0910,  0.0985],
#          [ 0.0989, -0.0942, -0.0085,  ..., -0.0243,  0.0091, -0.1147],
#          [ 0.0376, -0.0967, -0.0805,  ...,  0.0490,  0.1056, -0.0342],
#          ...,
#          [ 0.0304,  0.0586, -0.0396,  ...,  0.0959, -0.0551,  0.0263],
#          [-0.0018,  0.0575,  0.0189,  ...,  0.0325,  0.0596, -0.0834],
#          [ 0.0811, -0.1130, -0.0814,  ..., -0.1251, -0.0507,  0.0150]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.0221, -0.1156,  0.0925,  0.0917, -0.0776,  0.0141,  0.0799, -0.1183,
#          -0.1102,  0.0701, -0.0005,  0.0412, -0.0515,  0.0241,  0.0814, -0.0324,
#          -0.0367, -0.1175, -0.0173,  0.0824, -0.1213, -0.0098,  0.0899, -0.0315,
#          -0.0450, -0.0398, -0.0538,  0.0161, -0.1227,  0.0489, -0.0308, -0.0176,
#          -0.0059,  0.0697, -0.0787, -0.1139, -0.0871, -0.0928, -0.0615,  0.0967,
#          -0.0922, -0.0704, -0.0985, -0.0622, -0.0040, -0.0706,  0.0002,  0.0441,
#          -0.0242,  0.0560,  0.0277,  0.1167, -0.0102,  0.1077,  0.0950,  0.0585,
#           0.0695, -0.0859, -0.0806,  0.0509,  0.0465,  0.1135, -0.0168, -0.0186],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0855,  0.0048,  0.1160, -0.0648, -0.0433,  0.0068,  0.0636, -0.1092,
#          -0.0348,  0.0915,  0.0280,  0.0898, -0.0419, -0.0774, -0.0868, -0.0721,
#          -0.0902,  0.0635,  0.0356, -0.0768,  0.1114,  0.0355,  0.0453, -0.0485,
#           0.0877, -0.0903,  0.0880, -0.0668,  0.0507, -0.0441,  0.0819, -0.1065,
#          -0.0218, -0.0338, -0.0758, -0.0615, -0.0317,  0.0119,  0.0880, -0.0226,
#           0.1271, -0.0564, -0.0609, -0.0059, -0.0231,  0.0453,  0.1144,  0.0447,
#          -0.1075, -0.0407, -0.0258, -0.1178,  0.0348,  0.1084,  0.0635, -0.0037,
#          -0.0107, -0.0607, -0.0107,  0.1071, -0.0632,  0.0207, -0.0922, -0.0298],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.0106, -0.1333,  0.0483,  ..., -0.0657, -0.0841,  0.1392],
#          [ 0.1048,  0.0500, -0.0082,  ...,  0.1254, -0.1721, -0.0670],
#          [ 0.1269, -0.0140,  0.0626,  ..., -0.1796, -0.1635,  0.0781],
#          ...,
#          [ 0.1096,  0.0829,  0.0988,  ...,  0.0994,  0.0494, -0.0010],
#          [ 0.1580, -0.0098,  0.0625,  ..., -0.1526, -0.1628,  0.0604],
#          [ 0.1676, -0.0631,  0.1681,  ..., -0.0252,  0.0374, -0.1123]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.1471,  0.0800,  0.1119,  ..., -0.1356, -0.1590,  0.0235],
#          [-0.0638, -0.1007, -0.0365,  ..., -0.0362,  0.1157, -0.0450],
#          [ 0.1202, -0.0448,  0.0447,  ..., -0.0534, -0.1118, -0.1205],
#          ...,
#          [-0.0745,  0.0330, -0.1237,  ..., -0.0148,  0.1676,  0.1572],
#          [ 0.1343,  0.0382,  0.0033,  ..., -0.0853, -0.1756,  0.0605],
#          [ 0.0048,  0.1528,  0.0652,  ...,  0.0374, -0.1556,  0.0769]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.
#            2.6359e-02, -1.8344e-01,  3.6748e-02,  6.6258e-02, -2.3076e-01,
#           -1.7614e-01, -1.2399e-01, -8.7579e-02, -4.4852e-02,  1.0353e-01,
#           -1.9638e-01,  1.2863e-01, -1.7542e-01,  2.1624e-01, -1.4214e-01,
#           -1.8405e-01,  1.8029e-01,  2.0546e-01, -8.6013e-02,  2.2465e-01,
#            2.2923e-02,  8.7815e-02, -1.6025e-02, -6.3387e-02, -9.1339e-02,
#           -2.1944e-01,  1.8068e-01],
#          [ 1.3969e-01,  2.2924e-01, -2.4693e-01,  2.4673e-01,  1.6577e-01,
#            6.7404e-02, -1.0631e-01,  1.7846e-01,  1.6176e-01,  2.1126e-01,
#           -2.0180e-01,  3.8996e-02,  9.1303e-02, -2.4433e-01,  2.3274e-01,
#            1.5363e-01, -2.0245e-01, -2.1502e-01,  1.2715e-02,  1.9916e-01,
#            6.6143e-02,  3.3152e-02, -1.5656e-02, -2.4844e-01,  1.4657e-01,
#            1.6459e-01, -1.7509e-01, -4.7136e-02,  2.4005e-01, -9.7159e-02,
#           -1.6798e-01,  1.4216e-01]], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.1146,  0.2158, -0.1085,  0.0622,  0.0626,  0.2015,  0.1401,  0.0567,
#           -0.0352, -0.0453, -0.1395,  0.1082,  0.2130, -0.1275, -0.1693,  0.1850],
#          [ 0.0339, -0.1194,  0.1638, -0.2050, -0.1244, -0.0785, -0.0071,  0.0548,
#            0.1196, -0.0870, -0.0210, -0.1331, -0.1639,  0.0549,  0.1836,  0.2169],
#          [-0.1943,  0.1184, -0.0761, -0.0136, -0.0140,  0.2177,  0.2086, -0.2008,
#            0.0546,  0.1477,  0.0726, -0.0089, -0.1180, -0.1758, -0.2477, -0.0033],
#          [-0.0943,  0.0608, -0.1063,  0.2068, -0.1819,  0.2239, -0.1018,  0.0414,
#           -0.0902,  0.1077,  0.2033,  0.2302, -0.1732,  0.1731,  0.1633, -0.2025],
#          [ 0.1025,  0.0491,  0.1361,  0.2177,  0.0022, -0.0906, -0.1149,  0.0342,
#           -0.0365, -0.1778,  0.0129,  0.1398,  0.0079,  0.1575, -0.0969,  0.1972],
#          [ 0.0600, -0.0810,  0.1165,  0.1247, -0.1086, -0.0475,  0.1263, -0.2214,
#            0.0957,  0.0557, -0.1704, -0.0286,  0.0722,  0.1739,  0.1813, -0.1619],
#          [-0.1632,  0.1193,  0.2446,  0.2150,  0.1004,  0.2350, -0.1153, -0.0090,
#           -0.2039, -0.1539, -0.1731, -0.2238,  0.0703,  0.0643,  0.1016,  0.1645],
#          [-0.1979, -0.0711,  0.1943, -0.2186,  0.1757,  0.0756, -0.2041,  0.0544,
#            0.0066,  0.0479, -0.0721,  0.1147,  0.1918,  0.1716, -0.0302, -0.2331],
#          [ 0.2422,  0.0698,  0.2223,  0.0929,  0.0080,  0.1317,  0.1408, -0.0173,
#            0.0398, -0.0108,  0.1640,  0.1180, -0.0395,  0.2344,  0.2445,  0.2028],
#          [ 0.0460,  0.0159, -0.1313,  0.1811, -0.1830, -0.2136,  0.0741, -0.2313,
#            0.0804, -0.1192,  0.0021, -0.0994,  0.2025, -0.1849,  0.0446,  0.0053],
#          [-0.2373,  0.1859,  0.0528, -0.2044, -0.2438,  0.1131,  0.2104, -0.0573,
#           -0.0774, -0.2165,  0.1651, -0.0957, -0.1153,  0.0929,  0.2189,  0.1136],
#          [ 0.0722,  0.2207,  0.0123,  0.0379, -0.0205, -0.1554,  0.0460, -0.1274,
#            0.1455, -0.1715, -0.2009, -0.0506,  0.1869, -0.1887, -0.0796, -0.0173],
#          [-0.1095,  0.1227,  0.2158,  0.1380, -0.0562, -0.1991, -0.2103, -0.0611,
#           -0.0768, -0.1871,  0.0636, -0.0923,  0.0724, -0.1313, -0.0228, -0.0742],
#          [ 0.1531, -0.2252, -0.1010,  0.0551, -0.0710, -0.0063,  0.1661,  0.0356,
#            0.0321,  0.0740, -0.1363, -0.0976,  0.1200,  0.0369,  0.1638, -0.0322],
#          [ 0.2356,  0.1499, -0.0697, -0.1281,  0.0465, -0.2076, -0.1165,  0.0795,
#            0.0232,  0.1153, -0.0994,  0.2080, -0.1363, -0.1262,  0.1661, -0.0458],
#          [ 0.0705, -0.0431, -0.1792, -0.0076,  0.1152,  0.1656,  0.1897, -0.0095,
#            0.1820,  0.0705,  0.0044,  0.0086, -0.0230,  0.0722, -0.0109,  0.1603]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([-0.0381, -0.1391,  0.0725, -0.1407,  0.1554,  0.2044,  0.0402, -0.0485,
#          -0.0132,  0.1167, -0.1893, -0.0679, -0.1534, -0.2267, -0.1802, -0.1617],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.1903,  0.1526, -0.1699, -0.1979,  0.2240,  0.0596,  0.1152,  0.0407,
#          -0.0954, -0.1354,  0.1362, -0.2479, -0.2091,  0.0750, -0.0669,  0.0467],
#         requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.1319, -0.1464, -0.1361, -0.1543, -0.2134, -0.0164,  0.2146, -0.0168,
#            0.1357, -0.1266,  0.0194, -0.1834, -0.0161,  0.0540, -0.1049,  0.2272]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([0.0710], requires_grad=True)]

# %%
# Make predictions
model_0.eval()
y_train_preds = []

with torch.inference_mode():
    for X_batch, _ in train_loader:
        y_pred = model_0(X_batch)
        y_train_preds.append(y_pred)

# Concatenate all predictions into a single tensor
y_train_preds = torch.cat(y_train_preds)

print("Predictions shape:", y_train_preds.shape)  # Should be (2583, 1)
# Out:
# Predictions shape: torch.Size([7743, 1])

# %%
# Make predictions
model_0.eval()
y_preds = []

with torch.inference_mode():
    for X_batch, _ in test_loader:
        y_pred = model_0(X_batch)
        y_preds.append(y_pred)

# Concatenate all predictions into a single tensor
y_preds = torch.cat(y_preds)

print("Predictions shape:", y_preds.shape)  # Should be (2583, 1)
# Out:
# Predictions shape: torch.Size([2583, 1])

# %%
prediction_train_np = y_train_preds.numpy()
prediction_train_np.shape
# Out:
# (7743, 1)

# %%
prediction_np = y_preds.numpy()
prediction_np.shape
# Out:
# (2583, 1)

# %%
# model train vs test
y_train_np = y_train.reshape(prediction_train_np.shape[0],1)
y_test_np = y_test.reshape(prediction_np.shape[0],1)

# %%
epoch_list = list(range(0,epochs,10))

# %%
import matplotlib.pyplot as plt

# %%
epoch_list = list(range(10,epochs+1,10))

plt.plot(epoch_list,train_loss_values,label='train loss',color='blue')
plt.plot(epoch_list,test_loss_values,label='test loss',color = 'red')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.title('Train vs Test Loss RNN')

plt.legend()

plt.show()

# %% [markdown]
# # Combining return and data

# %% [markdown]
# ## training data

# %%
close_train =  df.loc[X_train_check.iloc[6:].index].close.values

# %%
close_train_t1 = df.loc[X_train_check.iloc[5:-1].index].close.values
close_train_prediction = np.log(close_train_t1)+prediction_train_np.reshape(7743)
predicted_price_train = np.exp(close_train_prediction)

# %%
predicted_price_train.shape
# Out:
# (7743,)

# %%
close_real = df.loc[df.open_time>='2023-7-28 19:00'].close.values # real data
print(close_real)
close_real.shape
# Out:
# [1874.74 1873.4  1873.39 ... 2595.05 2594.49 2601.49]
# (2583,)

# %%
# first y_hat that we get is to predicting return 
close_pred = np.log(df.loc[df.open_time>='2023-7-28 15:00'].close.values[:-1])
close_pred_logged = close_pred.reshape(close_pred.shape[0],1) + prediction_np

# %%
close_hat = np.exp(close_pred_logged)
close_hat.shape
# Out:
# (2583, 1)

# %%
prediction_np.shape
# Out:
# (2583, 1)

# %%
y_test.shape[0]
# Out:
# 2583

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import root_mean_squared_error as rmse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_absolute_percentage_error as mape

# %% [markdown]
# # return error

# %% [markdown]
# ## train data price error

# %%
mse(predicted_price_train,close_train)
# Out:
# 1943.9609315769872

# %%
rmse(predicted_price_train,close_train)
# Out:
# 44.090372322957165

# %%
mae(predicted_price_train,close_train)
# Out:
# 25.156197532682484

# %%
mape(predicted_price_train,close_train)
# Out:
# 0.013974251913950592

# %% [markdown]
# ## train data return error

# %%
mse(prediction_train_np,y_train)
# Out:
# 0.00042803178075701

# %%
rmse(prediction_train_np,y_train)
# Out:
# 0.02068892866373062

# %%
mae(prediction_train_np,y_train)
# Out:
# 0.013943573459982872

# %%
mape(prediction_train_np,y_train)
# Out:
# 17.85120391845703

# %% [markdown]
# ## test data

# %%
mse(prediction_np,y_test)
# Out:
# 0.0002162266318919137

# %%
rmse(prediction_np,y_test)
# Out:
# 0.014704646542668343

# %%
mae(prediction_np,y_test)
# Out:
# 0.009837973862886429

# %%
mape(prediction_np,y_test)
# Out:
# 9.611566543579102

# %%
XY_data
# Out:
#                      ret_close      rsi14      rsi21  BBP_30_2.0  BBP_31_2.0  \
# open_time
# 2020-01-09 11:00:00  -0.000143  50.827852  53.502023    0.533342    0.545253
# 2020-01-09 15:00:00  -0.012225  46.592383  50.203579    0.395587    0.412719
# 2020-01-09 19:00:00  -0.000651  46.372073  50.032115    0.368387    0.390964
# 2020-01-09 23:00:00  -0.004281  44.874082  48.882925    0.298975    0.325386
# 2020-01-10 03:00:00   0.001453  45.516591  49.297440    0.293984    0.320568
# ...                        ...        ...        ...         ...         ...
# 2024-09-30 11:00:00   0.003062  46.236617  50.622382    0.405491    0.412349
# 2024-09-30 15:00:00  -0.003316  43.949577  49.088132    0.336007    0.340391
# 2024-09-30 19:00:00  -0.012606  36.598073  43.828611    0.080785    0.101049
# 2024-09-30 23:00:00  -0.000216  36.486268  43.744894    0.044491    0.101339
# 2024-10-01 03:00:00   0.002694  38.995063  45.120723    0.074759    0.124045
#
#                      MACDh_12_26_9         y
# open_time
# 2020-01-09 11:00:00      -0.758915 -0.012225
# 2020-01-09 15:00:00      -0.859642 -0.000651
# 2020-01-09 19:00:00      -0.900565 -0.004281
# 2020-01-09 23:00:00      -0.931715  0.001453
# 2020-01-10 03:00:00      -0.902566 -0.005752
# ...                            ...       ...
# 2024-09-30 11:00:00      -6.855071 -0.003316
# 2024-09-30 15:00:00      -7.393437 -0.012606
# 2024-09-30 19:00:00      -9.526301 -0.000216
# 2024-09-30 23:00:00     -10.459905  0.002694
# 2024-10-01 03:00:00     -10.086594       NaN
#
# [10338 rows x 7 columns]

# %% [markdown]
# # Plotting

# %%
train_date = X_train_check.iloc[6:].index
test_date = XY_data.index[XY_data.index>='2023-7-28 19:00']

# %%
combined_date = np.concatenate((train_date,test_date))
combined_return_pred = np.concatenate((prediction_train_np,prediction_np))
combined_return_real = np.concatenate((y_train,y_test))

# %%
plt.plot(combined_date,combined_return_real, label = 'real',color='blue')

plt.plot(combined_date,combined_return_pred,label = 'prediction',color='red')
plt.axvline(test_date[0],color='green', linestyle='--', label='Start of Test Data')

plt.xlabel(
    'Time'
)
plt.ylabel('Log Return')
# plt.plot(y_test, label = 'real')
plt.title("Prediction vs Real Return ETH RNN")
plt.legend()
plt.show()

# %% [markdown]
# # price error

# %%
mse(close_real,close_hat)
# Out:
# 1868.276018320911

# %%
rmse(close_real,close_hat)
# Out:
# 43.2235586031612

# %%
mae(close_real,close_hat)
# Out:
# 27.14390621583453

# %%
mape(close_real,close_hat)
# Out:
# 0.009814938214505537

# %%
combined_price_prediction = np.concatenate((predicted_price_train,close_hat.reshape(2583)))
combined_real_price = np.concatenate((close_train,close_real))

# %%
plt.figure(figsize=(8,8))
plt.plot(combined_date,combined_real_price, label = 'real',color='blue')

plt.plot(combined_date,combined_price_prediction,label = 'prediction',color='red')
plt.axvline(test_date[0],color='green', linestyle='--', label='Start of Test Data')

plt.xlabel(
    'Time'
)
plt.ylabel('Log Return')
# plt.plot(y_test, label = 'real')
plt.title("Prediction vs Real Price ETH RNN")
plt.legend()
plt.show()

# %%
plt.hist(prediction_np,bins=50,label = 'prediction',color='red',alpha=0.5)
plt.hist(y_test,bins=50,label='real',color='blue',alpha=0.8)
plt.title("Histogram Prediction vs Real Log Return ETH BiDirectional RNN")
plt.xlabel(
    'Log Return'
)
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Pastikan bin edges sama untuk kedua histogram
combined_data = np.concatenate([prediction_np.reshape(2583,), y_test])
bin_edges = np.histogram_bin_edges(combined_data, bins=50)

# Buat subplot dengan tata letak 2 baris, 1 kolom
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# Histogram atas (prediction)
ax1.hist(prediction_np, bins=bin_edges, color='red', alpha=0.5, label='Prediction')
ax1.set_ylabel('Frequency')
ax1.set_ylim([0, 800])
ax1.legend()
ax1.set_title('Prediction vs Real Log Return ETH RNN MSE Loss')

# Histogram bawah (real)
ax2.hist(y_test, bins=bin_edges, color='blue', alpha=0.8, label='Real')
ax2.set_xlabel('Log Return')
ax2.set_ylabel('Frequency')
ax2.set_ylim([0, 800])
ax2.legend()

plt.tight_layout()

plt.show()
